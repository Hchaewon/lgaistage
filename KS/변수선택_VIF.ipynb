# %%
# 패키지 로드
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from collections import defaultdict
import os, random

from scipy import sparse
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
from torch.nn.init import normal_
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

#import plotnine
#from plotnine import *

# %%
# 경로 설정
data_path = '/Users/kyoungseo/lgupls_aistage/data/'

# %%
# 데이터 불러오기 
df = pd.read_csv(os.path.join(data_path, 'sample.csv'), encoding='utf-8')

# %%
df = df.drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#    profile_id  album_id                ss_id           log_time_x  \
# 0           3      15.0  2022-03-01 11:56:53  2022-03-01 11:57:19
# 1           3      16.0  2022-03-01 11:56:53  2022-03-01 11:58:09
# 2           3      17.0  2022-03-01 11:56:53  2022-03-01 11:59:58
# 3           3      18.0  2022-03-01 11:56:53  2022-03-01 12:01:18
# 4           3      19.0  2022-03-01 11:56:53  2022-03-01 12:02:29
#
#             log_time_y             diff  diff_ss  diff_ox  watch_time  \
# 0  2022-03-01 11:58:05  0 days 00:00:46     46.0     True        46.0
# 1  2022-03-01 11:59:54  0 days 00:01:45    105.0    False       104.0
# 2  2022-03-01 12:01:14  0 days 00:01:16     76.0     True        76.0
# 3  2022-03-01 12:02:26  0 days 00:01:08     68.0    False        67.0
# 4  2022-03-01 12:04:00  0 days 00:01:31     91.0    False        90.0
#
#    total_time  ... search_ox  prefer sex age pr_interest_keyword_cd_1  \
# 0        46.0  ...       0.0     4.0   F   5                      P02
# 1       105.0  ...       0.0     4.0   F   5                      P02
# 2        76.0  ...       0.0     4.0   F   5                      P02
# 3        68.0  ...       0.0     4.0   F   5                      P02
# 4        90.0  ...       0.0     4.0   F   5                      P02
#
#    pr_interest_keyword_cd_2  pr_interest_keyword_cd_3  \
# 0                       P04                       P07
# 1                       P04                       P07
# 2                       P04                       P07
# 3                       P04                       P07
# 4                       P04                       P07
#
#    ch_interest_keyword_cd_1  ch_interest_keyword_cd_2 ch_interest_keyword_cd_3
# 0                       K01                       K03                      K04
# 1                       K01                       K03                      K04
# 2                       K01                       K03                      K04
# 3                       K01                       K03                      K04
# 4                       K01                       K03                      K04
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['profile_id', 'album_id', 'ss_id', 'log_time_x', 'log_time_y', 'diff',
#        'diff_ss', 'diff_ox', 'watch_time', 'total_time', 'continuous_play_x',
#        'continuous_play_y', 'act_target_dtl_x', 'act_target_dtl',
#        'short_trailer', 'payment', 'time_slot', 'search_ox', 'prefer', 'sex',
#        'age', 'pr_interest_keyword_cd_1', 'pr_interest_keyword_cd_2',
#        'pr_interest_keyword_cd_3', 'ch_interest_keyword_cd_1',
#        'ch_interest_keyword_cd_2', 'ch_interest_keyword_cd_3'],
#       dtype='object')

# %%
X = df.loc[:, ~df.columns.isin(['album_id'])] # FEATURE DATA
y = df['album_id'] # LABEL DATA

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, test_size = 0.2)

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
# %%time

# 전부 int or float형으로 바꾸고 돌려야 함

# extract effective features using variance inflation factor
vif = pd.DataFrame()

# variance_inflation_factor(X, i) : Xi를 x나머지로 회귀분석한 후 VIF값을 구한것. 즉 xi의 vif값. 즉 이값이 높을수록 종속성이 높다는 뜻

vif['VIF_Factor'] = [variance_inflation_factor(X.values, i) 
                     for i in range(X.shape[1])]
vif['Feature'] = X.columns
vif.sort_values(by='VIF_Factor', ascending=True)
# Out:
# Wall time: 1min 49s
#               VIF_Factor                          Feature
# 0                0.99999                       profile_id
# 11               1.00000                        search_ox
# 7                1.00001                continuous_play_y
# 16               1.00016  pr_interest_keyword_cd_2_encode
# 9                1.00024                          payment
# 6                1.00075                       total_time
# 10               1.00152                        time_slot
# 14               1.00160                              age
# 17               1.00195  pr_interest_keyword_cd_3_encode
# 19               1.00241  ch_interest_keyword_cd_2_encode
# 18               1.00332  ch_interest_keyword_cd_1_encode
# 20               1.00368  ch_interest_keyword_cd_3_encode
# 15               1.00422  pr_interest_keyword_cd_1_encode
# 5                1.00850                       watch_time
# 12               1.01480                           prefer
# 1              472.82857                            ss_id
# 3  290554814669064.25000                       log_time_y
# 2  346430740566961.25000                       log_time_x
# 4                    inf                          diff_ss
# 8                    NaN                    short_trailer
# 13                   NaN                              sex

# %%
X.corr()
# Out:
#                                  profile_id  album_id    ss_id  log_time_x  \
# profile_id                          1.00000   0.01412 -0.00420    -0.00432
# album_id                            0.01412   1.00000 -0.00921    -0.00971
# ss_id                              -0.00420  -0.00921  1.00000     0.99886
# log_time_x                         -0.00432  -0.00971  0.99886     1.00000
# log_time_y                         -0.00432  -0.00968  0.99883     0.99961
# diff_ss                            -0.00015   0.00112 -0.00050    -0.01348
# diff_ox                             0.04314  -0.00531 -0.01609    -0.01828
# watch_time                         -0.00119  -0.02097 -0.03181    -0.02782
# total_time                         -0.02353   0.16895 -0.03795    -0.03875
# continuous_play_y                   0.00161  -0.06114 -0.00120    -0.00109
# short_trailer                           NaN       NaN      NaN         NaN
# payment                             0.00223  -0.02036 -0.02773    -0.02705
# time_slot                           0.03616   0.00871 -0.01417    -0.01500
# search_ox                          -0.00122   0.00379  0.00352     0.00351
# prefer                             -0.05227  -0.13856 -0.00125     0.00371
# sex                                     NaN       NaN      NaN         NaN
# age                                 0.02959   0.16907 -0.05022    -0.05165
# pr_interest_keyword_cd_1_encode    -0.06337  -0.01263  0.03214     0.03195
# pr_interest_keyword_cd_2_encode    -0.00006  -0.03735  0.01639     0.01678
# pr_interest_keyword_cd_3_encode    -0.04477  -0.01525 -0.01759    -0.01787
# ch_interest_keyword_cd_1_encode    -0.04866  -0.05952  0.03602     0.03743
# ch_interest_keyword_cd_2_encode    -0.04802  -0.06322  0.02151     0.02138
# ch_interest_keyword_cd_3_encode    -0.05321  -0.05918  0.05205     0.05331
#
#                                  log_time_y  diff_ss  diff_ox  watch_time  \
# profile_id                         -0.00432 -0.00015  0.04314    -0.00119
# album_id                           -0.00968  0.00112 -0.00531    -0.02097
# ss_id                               0.99883 -0.00050 -0.01609    -0.03181
# log_time_x                          0.99961 -0.01348 -0.01828    -0.02782
# log_time_y                          1.00000  0.01432 -0.01834    -0.02745
# diff_ss                             0.01432  1.00000 -0.00201     0.01330
# diff_ox                            -0.01834 -0.00201  1.00000     0.07526
# watch_time                         -0.02745  0.01330  0.07526     1.00000
# total_time                         -0.03864  0.00379 -0.00839     0.17328
# continuous_play_y                  -0.00118 -0.00321  0.00521    -0.00182
# short_trailer                           NaN      NaN      NaN         NaN
# payment                            -0.02703  0.00079  0.00089     0.01018
# time_slot                          -0.01475  0.00916  0.01541    -0.01367
# search_ox                           0.00351  0.00000 -0.00138     0.00234
# prefer                              0.00382  0.00398  0.04342     0.52287
# sex                                     NaN      NaN      NaN         NaN
# age                                -0.05166 -0.00025  0.05940     0.14445
# pr_interest_keyword_cd_1_encode     0.03204  0.00321 -0.03319    -0.04981
# pr_interest_keyword_cd_2_encode     0.01686  0.00292 -0.02791    -0.06254
# pr_interest_keyword_cd_3_encode    -0.01774  0.00435 -0.01971    -0.04898
# ch_interest_keyword_cd_1_encode     0.03733 -0.00371 -0.05771    -0.10585
# ch_interest_keyword_cd_2_encode     0.02132 -0.00221 -0.03298    -0.08322
# ch_interest_keyword_cd_3_encode     0.05325 -0.00234 -0.05263    -0.07241
#
#                                  total_time  continuous_play_y  ...  \
# profile_id                         -0.02353            0.00161  ...
# album_id                            0.16895           -0.06114  ...
# ss_id                              -0.03795           -0.00120  ...
# log_time_x                         -0.03875           -0.00109  ...
# log_time_y                         -0.03864           -0.00118  ...
# diff_ss                             0.00379           -0.00321  ...
# diff_ox                            -0.00839            0.00521  ...
# watch_time                          0.17328           -0.00182  ...
# total_time                          1.00000           -0.08733  ...
# continuous_play_y                  -0.08733            1.00000  ...
# short_trailer                           NaN                NaN  ...
# payment                            -0.03140           -0.01738  ...
# time_slot                           0.01397           -0.01862  ...
# search_ox                           0.00214           -0.00352  ...
# prefer                             -0.31483            0.05898  ...
# sex                                     NaN                NaN  ...
# age                                 0.24408           -0.12599  ...
# pr_interest_keyword_cd_1_encode     0.01841           -0.01779  ...
# pr_interest_keyword_cd_2_encode    -0.02568            0.01465  ...
# pr_interest_keyword_cd_3_encode    -0.04870           -0.01304  ...
# ch_interest_keyword_cd_1_encode    -0.13913            0.09071  ...
# ch_interest_keyword_cd_2_encode    -0.13332            0.03447  ...
# ch_interest_keyword_cd_3_encode    -0.11403            0.04068  ...
#
#                                  search_ox   prefer  sex      age  \
# profile_id                        -0.00122 -0.05227  NaN  0.02959
# album_id                           0.00379 -0.13856  NaN  0.16907
# ss_id                              0.00352 -0.00125  NaN -0.05022
# log_time_x                         0.00351  0.00371  NaN -0.05165
# log_time_y                         0.00351  0.00382  NaN -0.05166
# diff_ss                            0.00000  0.00398  NaN -0.00025
# diff_ox                           -0.00138  0.04342  NaN  0.05940
# watch_time                         0.00234  0.52287  NaN  0.14445
# total_time                         0.00214 -0.31483  NaN  0.24408
# continuous_play_y                 -0.00352  0.05898  NaN -0.12599
# short_trailer                          NaN      NaN  NaN      NaN
# payment                           -0.00043  0.05009  NaN  0.00535
# time_slot                          0.00293 -0.06383  NaN  0.00902
# search_ox                          1.00000 -0.00045  NaN  0.00037
# prefer                            -0.00045  1.00000  NaN -0.12227
# sex                                    NaN      NaN  NaN      NaN
# age                                0.00037 -0.12227  NaN  1.00000
# pr_interest_keyword_cd_1_encode    0.00344  0.00064  NaN -0.06645
# pr_interest_keyword_cd_2_encode   -0.00124 -0.00069  NaN -0.09672
# pr_interest_keyword_cd_3_encode   -0.00261 -0.01133  NaN -0.13513
# ch_interest_keyword_cd_1_encode    0.00089  0.08798  NaN -0.35416
# ch_interest_keyword_cd_2_encode    0.00171  0.05329  NaN -0.24916
# ch_interest_keyword_cd_3_encode   -0.00302  0.07184  NaN -0.28189
#
#                                  pr_interest_keyword_cd_1_encode  \
# profile_id                                              -0.06337
# album_id                                                -0.01263
# ss_id                                                    0.03214
# log_time_x                                               0.03195
# log_time_y                                               0.03204
# diff_ss                                                  0.00321
# diff_ox                                                 -0.03319
# watch_time                                              -0.04981
# total_time                                               0.01841
# continuous_play_y                                       -0.01779
# short_trailer                                                NaN
# payment                                                  0.03044
# time_slot                                               -0.02825
# search_ox                                                0.00344
# prefer                                                   0.00064
# sex                                                          NaN
# age                                                     -0.06645
# pr_interest_keyword_cd_1_encode                          1.00000
# pr_interest_keyword_cd_2_encode                          0.14852
# pr_interest_keyword_cd_3_encode                          0.19411
# ch_interest_keyword_cd_1_encode                          0.07216
# ch_interest_keyword_cd_2_encode                          0.02796
# ch_interest_keyword_cd_3_encode                         -0.01646
#
#                                  pr_interest_keyword_cd_2_encode  \
# profile_id                                              -0.00006
# album_id                                                -0.03735
# ss_id                                                    0.01639
# log_time_x                                               0.01678
# log_time_y                                               0.01686
# diff_ss                                                  0.00292
# diff_ox                                                 -0.02791
# watch_time                                              -0.06254
# total_time                                              -0.02568
# continuous_play_y                                        0.01465
# short_trailer                                                NaN
# payment                                                  0.00865
# time_slot                                               -0.01794
# search_ox                                               -0.00124
# prefer                                                  -0.00069
# sex                                                          NaN
# age                                                     -0.09672
# pr_interest_keyword_cd_1_encode                          0.14852
# pr_interest_keyword_cd_2_encode                          1.00000
# pr_interest_keyword_cd_3_encode                          0.17548
# ch_interest_keyword_cd_1_encode                          0.13937
# ch_interest_keyword_cd_2_encode                          0.05181
# ch_interest_keyword_cd_3_encode                          0.05710
#
#                                  pr_interest_keyword_cd_3_encode  \
# profile_id                                              -0.04477
# album_id                                                -0.01525
# ss_id                                                   -0.01759
# log_time_x                                              -0.01787
# log_time_y                                              -0.01774
# diff_ss                                                  0.00435
# diff_ox                                                 -0.01971
# watch_time                                              -0.04898
# total_time                                              -0.04870
# continuous_play_y                                       -0.01304
# short_trailer                                                NaN
# payment                                                  0.00567
# time_slot                                                0.02268
# search_ox                                               -0.00261
# prefer                                                  -0.01133
# sex                                                          NaN
# age                                                     -0.13513
# pr_interest_keyword_cd_1_encode                          0.19411
# pr_interest_keyword_cd_2_encode                          0.17548
# pr_interest_keyword_cd_3_encode                          1.00000
# ch_interest_keyword_cd_1_encode                          0.03253
# ch_interest_keyword_cd_2_encode                         -0.00750
# ch_interest_keyword_cd_3_encode                         -0.01471
#
#                                  ch_interest_keyword_cd_1_encode  \
# profile_id                                              -0.04866
# album_id                                                -0.05952
# ss_id                                                    0.03602
# log_time_x                                               0.03743
# log_time_y                                               0.03733
# diff_ss                                                 -0.00371
# diff_ox                                                 -0.05771
# watch_time                                              -0.10585
# total_time                                              -0.13913
# continuous_play_y                                        0.09071
# short_trailer                                                NaN
# payment                                                 -0.00233
# time_slot                                               -0.00306
# search_ox                                                0.00089
# prefer                                                   0.08798
# sex                                                          NaN
# age                                                     -0.35416
# pr_interest_keyword_cd_1_encode                          0.07216
# pr_interest_keyword_cd_2_encode                          0.13937
# pr_interest_keyword_cd_3_encode                          0.03253
# ch_interest_keyword_cd_1_encode                          1.00000
# ch_interest_keyword_cd_2_encode                          0.28770
# ch_interest_keyword_cd_3_encode                          0.26018
#
#                                  ch_interest_keyword_cd_2_encode  \
# profile_id                                              -0.04802
# album_id                                                -0.06322
# ss_id                                                    0.02151
# log_time_x                                               0.02138
# log_time_y                                               0.02132
# diff_ss                                                 -0.00221
# diff_ox                                                 -0.03298
# watch_time                                              -0.08322
# total_time                                              -0.13332
# continuous_play_y                                        0.03447
# short_trailer                                                NaN
# payment                                                  0.01365
# time_slot                                               -0.03271
# search_ox                                                0.00171
# prefer                                                   0.05329
# sex                                                          NaN
# age                                                     -0.24916
# pr_interest_keyword_cd_1_encode                          0.02796
# pr_interest_keyword_cd_2_encode                          0.05181
# pr_interest_keyword_cd_3_encode                         -0.00750
# ch_interest_keyword_cd_1_encode                          0.28770
# ch_interest_keyword_cd_2_encode                          1.00000
# ch_interest_keyword_cd_3_encode                          0.42789
#
#                                  ch_interest_keyword_cd_3_encode
# profile_id                                              -0.05321
# album_id                                                -0.05918
# ss_id                                                    0.05205
# log_time_x                                               0.05331
# log_time_y                                               0.05325
# diff_ss                                                 -0.00234
# diff_ox                                                 -0.05263
# watch_time                                              -0.07241
# total_time                                              -0.11403
# continuous_play_y                                        0.04068
# short_trailer                                                NaN
# payment                                                 -0.01596
# time_slot                                               -0.05341
# search_ox                                               -0.00302
# prefer                                                   0.07184
# sex                                                          NaN
# age                                                     -0.28189
# pr_interest_keyword_cd_1_encode                         -0.01646
# pr_interest_keyword_cd_2_encode                          0.05710
# pr_interest_keyword_cd_3_encode                         -0.01471
# ch_interest_keyword_cd_1_encode                          0.26018
# ch_interest_keyword_cd_2_encode                          0.42789
# ch_interest_keyword_cd_3_encode                          1.00000
#
# [23 rows x 23 columns]

# %%
# %%time
for i in ['pr_interest_keyword_cd_1', 'pr_interest_keyword_cd_2', 'pr_interest_keyword_cd_3',
          'ch_interest_keyword_cd_1', 'ch_interest_keyword_cd_2', 'ch_interest_keyword_cd_3'] : 
    enc_1 = (df.groupby(i).size()) / len(df)
    enc_1
    
    df['{}_encode'.format(i)] = df[i].apply(lambda x : enc_1[x])
    
#인코딩 전 변수는 제거 
df = df.drop(['pr_interest_keyword_cd_1', 'pr_interest_keyword_cd_2', 'pr_interest_keyword_cd_3',
                'ch_interest_keyword_cd_1', 'ch_interest_keyword_cd_2', 'ch_interest_keyword_cd_3'],axis=1)
# Out:
# Wall time: 2min 26s

# %%
df['short_trailer'] = df['short_trailer'].apply(lambda x: 1 if x == 'Y' else 0)
df['sex'] = df['sex'].apply(lambda x: 1 if x == 'M' else 0)

# %%
X['ss_id'] = pd.to_numeric(pd.to_datetime(X['ss_id']))
X['log_time_x'] = pd.to_numeric(pd.to_datetime(X['log_time_x']))
X['log_time_y'] = pd.to_numeric(pd.to_datetime(X['log_time_y']))

# %%
X = X.drop(['log_time_x', 'log_time_y', 'diff', 'diff_ox', 'continuous_play_x', 'act_target_dtl_x', 'act_target_dtl'], axis = 1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1914994 entries, 0 to 1914993
# Data columns (total 21 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   profile_id                int64
#  1   ss_id                     int64
#  2   log_time_x                int64
#  3   log_time_y                int64
#  4   diff_ss                   float64
#  5   watch_time                float64
#  6   total_time                float64
#  7   continuous_play_y         float64
#  8   short_trailer             object
#  9   payment                   float64
#  10  time_slot                 float64
#  11  search_ox                 float64
#  12  prefer                    float64
#  13  sex                       object
#  14  age                       int64
#  15  pr_interest_keyword_cd_1  object
#  16  pr_interest_keyword_cd_2  object
#  17  pr_interest_keyword_cd_3  object
#  18  ch_interest_keyword_cd_1  object
#  19  ch_interest_keyword_cd_2  object
#  20  ch_interest_keyword_cd_3  object
# dtypes: float64(8), int64(5), object(8)
# memory usage: 306.8+ MB
